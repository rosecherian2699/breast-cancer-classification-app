# %%
# %run train_models.py
# Out:
# Dataset shape: 569 instances, 30 features
# Class distribution:
# target
# 1    357
# 0    212
# Name: count, dtype: int64
#
# Saved test_data.csv with 114 rows.
#
# Logistic Regression: Accuracy=0.9649, AUC=0.9974, Precision=0.9857, Recall=0.9583, F1=0.9718, MCC=0.9260
# Decision Tree: Accuracy=0.9737, AUC=0.9742, Precision=0.9859, Recall=0.9722, F1=0.9790, MCC=0.9439
# kNN: Accuracy=0.9737, AUC=0.9950, Precision=0.9600, Recall=1.0000, F1=0.9796, MCC=0.9442
# Naive Bayes: Accuracy=0.9211, AUC=0.9821, Precision=0.9437, Recall=0.9306, F1=0.9371, MCC=0.8313
# Random Forest: Accuracy=0.9561, AUC=0.9960, Precision=0.9855, Recall=0.9444, F1=0.9645, MCC=0.9085
#
# Comparison table:
#
#                      Accuracy     AUC  Precision  Recall      F1     MCC
# ML Model Name
# Logistic Regression    0.9649  0.9974     0.9857  0.9583  0.9718  0.9260
# Decision Tree          0.9737  0.9742     0.9859  0.9722  0.9790  0.9439
# ...

# %%
# !cat README.md
# Out:
# cat: README.md: No such file or directory
